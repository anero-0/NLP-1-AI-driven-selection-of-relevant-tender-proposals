# %% [markdown]
# # Сравнение с CatBoost / XGBoost
# В данном ноутбуке мы обучаем градиентный бустинг для задачи бинарной классификации (Task 4).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score
from catboost import CatBoostClassifier

# Пример загрузки данных (предполагается что фичи уже собраны)
# df = pd.read_csv('data/processed_tenders.csv')
# X = df.drop(columns=['target'])
# y = df['target']

# Разбиение без перемешивания для имитации потока времени (Time-Series Split)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Обучение
# model = CatBoostClassifier(iterations=300, learning_rate=0.1, depth=6, verbose=50)
# model.fit(X_train, y_train)

# Оценка
# preds = model.predict(X_test)
# print(classification_report(y_test, preds))
